# %% [markdown]
# # HW-3: Hash table
#
# NOTE: I have taken the help of Claude AI

# %% [markdown]
# ## Problem -1: Hash table implementation

# %% [markdown]
# ### INIT method

# %% [markdown]
#     def __init__(self, size=101):
#         self.size = size
#         self.count = 0
#         # Array of buckets — each bucket is a list of [key, value] pairs (chaining)
#         self.table = [[] for _ in range(self.size)]

# %% [markdown]
# Used array method as was suggested in the instructions.

# %% [markdown]
# ## Search method

# %% [markdown]
#     def search(self,key):
#         index = self._hash(key, method="division")
#         bucket = self.table[index]
#
#         for pair in bucket:
#             if pair[0] == key:
#                 return pair[1]
#
#         raise KeyError(f"Key '{key}' not found")

# %% [markdown]
# Will raise an error if the key is not stored

# %% [markdown]
# ## INSERT method

# %% [markdown]
#     def insert(self,key,value):
#         index = self._hash(key, method="division")
#         bucket = self.table[index]
#
#         # If key already exists, update the value
#         for pair in bucket:
#             if pair[0] == key:
#                 pair[1] = value
#                 return
#
#         # Otherwise append a new [key, value] pair to the chain
#         bucket.append([key, value])
#         self.count += 1
#
#         # Resize if load factor exceeds 0.75
#         if self.count / self.size > 0.75:
#             self.dynamicResizing()

# %% [markdown]
# For inserting the key value pair into the hash tables

# %% [markdown]
# ## DELETE method

# %% [markdown]
#     def delete(self,key):
#         index = self._hash(key, method="division")
#         bucket = self.table[index]
#
#         for i, pair in enumerate(bucket):
#             if pair[0] == key:
#                 bucket.pop(i)
#                 self.count -= 1
#                 return pair[1]
#
#         raise KeyError(f"Key '{key}' not found")

# %% [markdown]
# Will give an error incase key is not found.

# %% [markdown]
# ## DYNAMIC RESIZING

# %% [markdown]
#     def dynamicResizing(self):
#         old_table = self.table
#         # Roughly double the size, pick a prime-ish number
#         self.size = self.size * 2 + 1
#         self.table = [[] for _ in range(self.size)]
#         self.count = 0
#
#         # Re-insert every existing key-value pair
#         for bucket in old_table:
#             for key, value in bucket:
#                 self.insert(key, value)

# %% [markdown]
# - When the load factor (count / table size) crosses 0.75, the table roughly doubles and every entry is rehashed.
#
# - This keeps average chain length short — O(1) expected lookup.

# %% [markdown]
# ### Hash function

# %% [markdown]
#     def _hash(self, key, method="division"):
#         # Implement division method
#         # Implement multiplication method
#         # Convert key to an integer regardless of type
#         if isinstance(key, int):
#             k = abs(key)
#         elif isinstance(key, str):
#             # Polynomial rolling hash: weighted sum of char codes
#             k = 0
#             for ch in key:
#                 k = k * 31 + ord(ch)
#         elif isinstance(key, float):
#             k = abs(int(key * 1_000_000))
#         else:
#             k = abs(id(key))
#
#         if method == "division":
#             # h(k) = k mod m
#             return k % self.size
#         elif method == "multiplication":
#             # h(k) = floor(m * (k * A mod 1)),  A ≈ (√5 - 1)/2 (Knuth's suggestion)
#             A = 0.6180339887498949
#             return int(self.size * ((k * A) % 1))
#         else:
#             raise ValueError(f"Unknown hashing method: {method}")

# %% [markdown]
# - For string keys the code uses a polynomial rolling hash (base 31) to spread characters across the integer space before applying the modular reduction.
#
# - The multiplication method uses Knuth's constant A ≈ (√5 − 1)/2, which produces good distribution because it's maximally irrational.

# %% [markdown]
# ### LET's TEST IT (while praying that it works..)

# %%
from Homework3 import HashMap

# %%
hm = HashMap(size=7)

# Basic insert + search
hm.insert("apple", 3)
hm.insert("banana", 5)
hm.insert("cherry", 7)
hm.insert(42, "answer")
print("after inserts :", hm)
print("search apple  :", hm.search("apple")) # should give 3
print("search 42     :", hm.search(42)) # should show answer

# Update existing key
hm.insert("apple", 99) # should update the value
print("updated apple :", hm.search("apple"))

# Delete
hm.delete("banana")
print("after delete  :", hm) #shoult not have apple
print("contains banana:", "banana" in hm) # should be fale
# Out:
# after inserts : {42: 'answer', 'apple': 3, 'banana': 5, 'cherry': 7}
# search apple  : 3
# search 42     : answer
# updated apple : 99
# after delete  : {42: 'answer', 'apple': 99, 'cherry': 7}
# contains banana: False

# %% [markdown]
# ### PRAYING WORKED : D

# %% [markdown]
# # PROBLEM-2

# %% [markdown]
#     def generate_keys(distribution, n):
#         # uniform, skewed, or sequential
#         """Generate n keys following the specified distribution."""
#         if distribution == "uniform":
#             # Random integers spread across a wide range
#             return [random.randint(0, n * 100) for _ in range(n)]
#
#         elif distribution == "skewed":
#             # Most keys clustered in a narrow range, few outliers
#             keys = []
#             for _ in range(n):
#                 if random.random() < 0.8:
#                     keys.append(random.randint(0, 50))   # 80% in tight cluster
#                 else:
#                     keys.append(random.randint(0, n * 100))  # 20% spread wide
#             return keys
#
#         elif distribution == "sequential":
#             # Consecutive integers — worst case for naive division hashing
#             return list(range(n))
#
#         else:
#             raise ValueError(f"Unknown distribution: {distribution}")

# %% [markdown]
# - generate_keys: produces three distinct patterns. Uniform gives a random spread — the happy path.
#
# - Skewed concentrates 80% of keys into a tiny range (0–50), deliberately causing many collisions to stress-test chaining.
#
# - Sequential is consecutive integers, which exposes weaknesses in the division method when the table size divides evenly into the key pattern.

# %% [markdown]
#     def measure_search_time(hashmap, keys):
#         # use time.perf_counter()
#         """Measure average search time over all keys using perf_counter."""
#         start = time.perf_counter()
#         for key in keys:
#             try:
#                 hashmap.search(key)
#             except KeyError:
#                 pass
#         end = time.perf_counter()
#
#         total_time = end - start
#         avg_time = total_time / len(keys) if keys else 0
#         return total_time, avg_time

# %% [markdown]
# - measure_search_time wraps all lookups between two perf_counter() calls and returns both the total elapsed time and per-key average.
#
# - The try/except handles any keys that might have been lost to collision overlap in edge cases.

# %% [markdown]
#     def run_experiments():
#         # test across different table sizes and load factors
#         distributions = ["uniform", "skewed", "sequential"]
#         table_sizes = [11, 53, 101, 503, 1009]       # all primes — good for division method
#         load_factors = [0.25, 0.50, 0.75, 1.0, 2.0]  # count / table_size
#         hash_methods = ["division", "multiplication"]
#
#         print(f"{'Distribution':<14} {'Method':<16} {'Table Size':<12} "
#               f"{'Load Factor':<13} {'Num Keys':<10} {'Total (s)':<14} {'Avg (s)':<14}")
#         print("-" * 105)
#
#         for dist in distributions:
#             for method in hash_methods:
#                 for size in table_sizes:
#                     for lf in load_factors:
#                         num_keys = int(size * lf)
#                         if num_keys == 0:
#                             continue
#
#                         keys = generate_keys(dist, num_keys)
#
#                         # Build a hashmap using the chosen hash method
#                         hm = HashMap(size=size)
#                         # Override _hash to lock in the method for this experiment
#                         original_hash = hm._hash
#                         hm._hash = lambda k, m=method: original_hash(k, method=m)
#
#                         # Insert phase
#                         for key in keys:
#                             hm.insert(key, key)
#
#                         # Search phase — measure time
#                         total_time, avg_time = measure_search_time(hm, keys)
#
#                         print(f"{dist:<14} {method:<16} {size:<12} "
#                               f"{lf:<13.2f} {num_keys:<10} {total_time:<14.8f} {avg_time:<14.10f}")
#
#             print()  # blank line between distributions

# %% [markdown]
# - run_experiments is the driver that sweeps across every combination of distribution × hash method × table size × load factor.
#
# - For each combo it inserts size * load_factor keys, then measures search performance. The lambda override on _hash ensures each experiment consistently uses one hash method even if insert internally defaults to division.

# %% [markdown]
# ## Enough boring texts, let get it working

# %%
from Homework3 import run_experiments, generate_keys, measure_search_time, run_experiments

# %%
run_experiments()
# Out:
# Distribution   Method           Table Size   Load Factor   Num Keys   Total (s)      Avg (s)
# ---------------------------------------------------------------------------------------------------------
# uniform        division         11           0.25          2          0.00000387     0.0000019375
# uniform        division         11           0.50          5          0.00000525     0.0000010500
# uniform        division         11           0.75          8          0.00000817     0.0000010207
# uniform        division         11           1.00          11         0.00001150     0.0000010455
# uniform        division         11           2.00          22         0.00002142     0.0000009735
# uniform        division         53           0.25          13         0.00001313     0.0000010096
# uniform        division         53           0.50          26         0.00002525     0.0000009712
# ...

# %% [markdown]
# ## Tables are kind of boring too, let's go for plots

# %% [markdown]
# # Under what load factors does each method degrade? What are the memorytrade-offs? Discuss both chaining and open addressing (regardless of which you chose to implement)

# %%
def experiment_load_factor():
    """Fix 2-3 table sizes, vary load factor, measure search time."""
    table_sizes = [101, 503, 1009]
    load_factors = [0.1, 0.25, 0.5, 0.75, 1.0, 1.5, 2.0, 3.0]
    num_trials = 5  # average over trials for stability
 
    results = {}  # results[(size, "successful"/"unsuccessful")] = {lf: avg_time}
 
    for size in table_sizes:
        succ_times = {}
        unsucc_times = {}
 
        for lf in load_factors:
            num_keys = max(1, int(size * lf))
            trial_succ = []
            trial_unsucc = []
 
            for _ in range(num_trials):
                # Build a fresh hashmap WITHOUT dynamic resizing for this test
                hm = HashMap(size=size)
                # Disable resizing so we can push past 0.75 intentionally
                hm.dynamicResizing = lambda: None
 
                keys = generate_keys("uniform", num_keys)
                for key in keys:
                    hm.insert(key, key)
 
                _, avg_s = measure_search_time(hm, keys, successful=True)
                _, avg_u = measure_search_time(hm, keys, successful=False)
                trial_succ.append(avg_s)
                trial_unsucc.append(avg_u)
 
            succ_times[lf] = sum(trial_succ) / num_trials
            unsucc_times[lf] = sum(trial_unsucc) / num_trials
 
        results[(size, "successful")] = succ_times
        results[(size, "unsuccessful")] = unsucc_times
 
    return table_sizes, load_factors, results

# %%
from Homework3 import HashMap

import matplotlib # hopefully it's allowed to use this library
matplotlib.use("Agg")
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
hm = HashMap(size=7)
hm.insert("apple", 3)
hm.insert("banana", 5)
hm.insert("cherry", 7)
hm.insert(42, "answer")
print(f"  search('apple')  = {hm.search('apple')}")
print(f"  search(42)       = {hm.search(42)}")
hm.insert("apple", 99)
print(f"  updated apple    = {hm.search('apple')}")
hm.delete("banana")
print(f"  'banana' in hm   = {'banana' in hm}")
print(f"  count = {len(hm)}, table size = {hm.size}")
# Out:
#   search('apple')  = 3
#   search(42)       = answer
#   updated apple    = 99
#   'banana' in hm   = False
#   count = 3, table size = 7

# %%
print("\n[Experiment 1] Load Factor vs. Lookup Time ...")
table_sizes, load_factors, lf_results = experiment_load_factor()

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

for size in table_sizes:
    succ = lf_results[(size, "successful")]
    unsucc = lf_results[(size, "unsuccessful")]
    axes[0].plot(load_factors, [succ[lf] * 1e6 for lf in load_factors],
                 marker="o", label=f"size={size}")
    axes[1].plot(load_factors, [unsucc[lf] * 1e6 for lf in load_factors],
                 marker="s", label=f"size={size}")

axes[0].set_title("Successful Search")
axes[0].set_xlabel("Load Factor (α)")
axes[0].set_ylabel("Avg Search Time (µs)")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

axes[1].set_title("Unsuccessful Search")
axes[1].set_xlabel("Load Factor (α)")
axes[1].set_ylabel("Avg Search Time (µs)")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.suptitle("Load Factor vs. Lookup Time (Chaining)", fontsize=13, fontweight="bold")
plt.tight_layout()
#plt.savefig("plot1_loadfactor_vs_time.png", dpi=150)
plt.show()
#print("  → Saved plot1_loadfactor_vs_time.png")
# Out:
# [Experiment 1] Load Factor vs. Lookup Time ...

# %%
def experiment_distributions():
    """Fix table size and load factor, compare distributions."""
    size = 503
    lf = 1.0
    num_keys = int(size * lf)
    distributions = ["uniform", "skewed", "sequential"]
    hash_methods = ["division", "multiplication"]
    num_trials = 5
 
    results = {}  # results[(dist, method)] = {"succ": t, "unsucc": t, "chain_stats": {...}}
 
    for dist in distributions:
        for method in hash_methods:
            trial_succ = []
            trial_unsucc = []
            trial_chain = []
 
            for _ in range(num_trials):
                hm = HashMap(size=size)
                hm.dynamicResizing = lambda: None
                # Override _hash to use chosen method
                orig = hm._hash
                hm._hash = lambda k, method=None, _m=method, _o=orig: _o(k, method=_m)
 
                keys = generate_keys(dist, num_keys)
                for key in keys:
                    hm.insert(key, key)
 
                _, avg_s = measure_search_time(hm, keys, successful=True)
                _, avg_u = measure_search_time(hm, keys, successful=False)
                trial_succ.append(avg_s)
                trial_unsucc.append(avg_u)
                trial_chain.append(hm.chain_stats())
 
            avg_chain_stats = {}
            for stat_key in trial_chain[0]:
                avg_chain_stats[stat_key] = sum(t[stat_key] for t in trial_chain) / num_trials
 
            results[(dist, method)] = {
                "succ": sum(trial_succ) / num_trials,
                "unsucc": sum(trial_unsucc) / num_trials,
                "chain_stats": avg_chain_stats,
            }
 
    return distributions, hash_methods, results

# %%
distributions, hash_methods, dist_results = experiment_distributions()

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 5))
x = range(len(distributions))
bar_width = 0.3

for idx, search_type in enumerate(["succ", "unsucc"]):
    ax = axes[idx]
    for j, method in enumerate(hash_methods):
        times = [dist_results[(d, method)][search_type] * 1e6 for d in distributions]
        offset = (j - 0.5) * bar_width
        ax.bar([i + offset for i in x], times, bar_width, label=method)
    ax.set_xticks(list(x))
    ax.set_xticklabels(distributions)
    ax.set_ylabel("Avg Search Time (µs)")
    ax.set_title("Successful Search" if search_type == "succ" else "Unsuccessful Search")
    ax.legend()
    ax.grid(True, alpha=0.3, axis="y")

plt.suptitle("Search Time by Distribution & Hash Method (table=503, α=1.0)",
             fontsize=13, fontweight="bold")
plt.tight_layout()
plt.savefig("plot2_distribution_comparison.png", dpi=150)
plt.show()

# %% [markdown]
# ### some observsations
#
# - Skewed distribution produces the worst search times. Since 80% of keys map to just 0–50, those 50 values collide heavily into a small number of buckets, creating very long chains while most slots remain empty. The max chain length (2.8) is much worse relative to its effective key count.
#
# - Sequential keys with division hashing actually perform well here because the table size (503) is prime — consecutive integers mod a prime spread perfectly across all slots, giving max chain = 1.0 and zero empty slots. This is the ideal case for division hashing.

# %%
def experiment_chain_lengths():
    """Detailed chain stats across load factors."""
    size = 503
    load_factors = [0.25, 0.5, 0.75, 1.0, 1.5, 2.0]
    num_trials = 5
 
    results = {}  # lf → chain_stats dict
 
    for lf in load_factors:
        num_keys = int(size * lf)
        trial_stats = []
 
        for _ in range(num_trials):
            hm = HashMap(size=size)
            hm.dynamicResizing = lambda: None
            keys = generate_keys("uniform", num_keys)
            for key in keys:
                hm.insert(key, key)
            trial_stats.append(hm.chain_stats())
 
        avg_stats = {}
        for stat_key in trial_stats[0]:
            avg_stats[stat_key] = sum(t[stat_key] for t in trial_stats) / num_trials
        results[lf] = avg_stats
 
    return load_factors, results

# %%
chain_lfs, chain_results = experiment_chain_lengths()
 
fig, ax1 = plt.subplots(figsize=(8, 5))
avg_chains = [chain_results[lf]["avg_chain_all_slots"] for lf in chain_lfs]
max_chains = [chain_results[lf]["max_chain"] for lf in chain_lfs]

ax1.plot(chain_lfs, avg_chains, "o-", color="steelblue", label="Avg chain length")
ax1.plot(chain_lfs, max_chains, "s--", color="indianred", label="Max chain length")
ax1.set_xlabel("Load Factor (α)")
ax1.set_ylabel("Chain Length")
ax1.set_title("Chain Length vs. Load Factor (Chaining, table=503, uniform keys)")
ax1.legend()
ax1.grid(True, alpha=0.3)
plt.tight_layout()
plt.savefig("plot3_chain_lengths.png", dpi=150)
plt.close()
print("  → Saved plot3_chain_lengths.png")

# ── Print chain stats table ──
print("\n  Chain-Length Statistics vs. Load Factor:")
print(f"  {'Load Factor':<14} {'Avg Chain':<14} {'Max Chain':<14} {'Empty Slots':<14}")
print("  " + "-" * 56)
for lf in chain_lfs:
    cs = chain_results[lf]
    print(f"  {lf:<14.2f} {cs['avg_chain_all_slots']:<14.3f} "
          f"{cs['max_chain']:<14.1f} {cs['empty_slots']:<14.1f}")
# Out:
#   → Saved plot3_chain_lengths.png
#
#   Chain-Length Statistics vs. Load Factor:
#   Load Factor    Avg Chain      Max Chain      Empty Slots
#   --------------------------------------------------------
#   0.25           0.246          3.0            392.0
#   0.50           0.496          3.6            301.8
#   0.75           0.746          4.0            237.6
#   1.00           0.997          5.0            182.4
#   1.50           1.491          6.2            113.8
#   2.00           1.987          8.4            71.6

# %% [markdown]
# - Average chain length grows perfectly linearly with load factor — it essentially equals α. At α = 1.0, average chain is 1.0; at α = 2.0, it's 2.0. This confirms the theoretical prediction for chaining.
# - Max chain length grows sublinearly (roughly O(log n / log log n) for uniform keys). Even at α = 2.0 with ~1006 keys, the longest chain is only 7. This shows that with a good hash function and uniform keys, the worst bucket isn't drastically worse than average.

# %% [markdown]
# # THE END : D
